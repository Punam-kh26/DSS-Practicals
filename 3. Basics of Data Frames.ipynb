# %% [markdown]
# # Creating a series

# %%
# Exp 3

# %%
#Aim : Basics of Data Frames

# %%
#Name:Punam Khotele
#Year:3^rd
#Sec:C
#Roll No.:30
#sub:ET-I

# %%
import pandas as pd

# %%
#Creating Student Name list
Name = ["ABC","DEF","GHI","JKL","XYZ"]
Name #display
# Out:
# ['ABC', 'DEF', 'GHI', 'JKL', 'XYZ']

# %%
#Creating a series
Roll_list=pd.Series(Name,index=[1,2,3,4,5])
print(Roll_list)
# Out:
# 1    ABC
# 2    DEF
# 3    GHI
# 4    JKL
# 5    XYZ
# dtype: object

# %% [markdown]
# # Creating DataFrames

# %%
import pandas as pd

# %%
#Creating a dataframes
df=pd.DataFrame([[10,12,14,16],[11,18,15,13],[13,15,16,10]],
columns=["CD","DBMS","DSS","CAO"])

# %%
df
# Out:
#    CD  DBMS  DSS  CAO
# 0  10    12   14   16
# 1  11    18   15   13
# 2  13    15   16   10

# %%
df.shape
# Out:
# (3, 4)

# %%
df.size
# Out:
# 12

# %%
df.ndim
# Out:
# 2

# %% [markdown]
# # Adding Record (Row) to the data Frame

# %%
df2=pd.DataFrame([[10,12,14,16]],
columns=["CD","DBMS","DSS","CAO"])

# %%
df3 = df.append(df2,ignore_index=True)

# %%
df3
# Out:
#    CD  DBMS  DSS  CAO
# 0  10    12   14   16
# 1  11    18   15   13
# 2  13    15   16   10
# 3  10    12   14   16

# %%
df3.size
# Out:
# 16

# %%
df3.shape
# Out:
# (4, 4)

# %%
#Dimension
df3.ndim
# Out:
# 2

# %%
df3["DM"] = [12,24,16,18]

# %%
df3
# Out:
#    CD  DBMS  DSS  CAO  DM
# 0  10    12   14   16  12
# 1  11    18   15   13  24
# 2  13    15   16   10  16
# 3  10    12   14   16  18

# %%
#Delete a record = 1
df4=df3.drop(index=[1])

# %%
df4
# Out:
#    CD  DBMS  DSS  CAO  DM
# 0  10    12   14   16  12
# 2  13    15   16   10  16
# 3  10    12   14   16  18

# %%
# Deleting Attribute (Columns) from df3 dataframe

# %%
df5 = df3.drop(columns=["DM"])

# %%
df5
# Out:
#    CD  DBMS  DSS  CAO
# 0  10    12   14   16
# 1  11    18   15   13
# 2  13    15   16   10
# 3  10    12   14   16

# %%
#finding a mean of DSS
print("Mean of DSS : " ,df5["DSS"].mean())
# Out:
# Mean of DSS :  14.75

# %%
#Finding a median of DSS
print("Median of DSS : ",df5["DSS"].median())
# Out:
# Median of DSS :  14.5

# %%
#Finding a Mode of DSS
print("Mode of DSS : ",df5["DSS"].mode())
# Out:
# Mode of DSS :  0    14
# dtype: int64

# %%
#log and #ilog
